# %% [markdown]
# <a href="https://colab.research.google.com/github/JesusGonzalez3355/IB_IA_2022/blob/main/AI_Assignment1_JesusGonzalez_1896928.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
message = input("Hello, how would you like me to call you? ")
a = "John"
b = "Ana"
c = "Peter"
if (message == a):
  print("Pff, there are better names!")
elif (message == b):
  print ("Pff, there are better names!")
elif (message == c):
  print ("Pff, there are better names!")
else:
  print("Nice to meet you", message)
# Out:
# Hello, how would you like me to call you? Peter
# Pff, there are better names!

# %%
List = ["1","apple","book","45","soda","65","33","8","radio"]
print(List[8])

NewList = List.copy()
NewList.reverse()
print(NewList)
# Out:
# radio
# ['radio', '8', '33', '65', 'soda', '45', 'book', 'apple', '1']

# %%
Food = ["My","favorite","food","are","spaguetti","and","meat"]
for x in Food:
  print(x)
# Out:
# My
# favorite
# food
# are
# spaguetti
# and
# meat
